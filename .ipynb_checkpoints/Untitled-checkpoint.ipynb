# %%
import numpy as np
import pandas as pd
# Out:
# /Users/Alli_1/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/Alli_1/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %%
from matplotlib import rcParams

# %%
pip install ptitprince
# Out:
# Collecting ptitprince
#   Downloading ptitprince-0.3.1.tar.gz (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 12.8 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.16 in /Users/Alli_1/opt/anaconda3/lib/python3.9/site-packages (from ptitprince) (1.24.4)
# Collecting matplotlib>=3.9
#   Downloading matplotlib-3.9.4-cp39-cp39-macosx_10_12_x86_64.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 14.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: seaborn>=0.13.2 in /Users/Alli_1/opt/anaconda3/lib/python3.9/site-packages (from ptitprince) (0.13.2)
# Requirement already satisfied: scipy in /Users/Alli_1/opt/anaconda3/lib/python3.9/site-packages (from ptitprince) (1.9.1)
# Requirement already satisfied: packaging>=20.0 in /Users/Alli_1/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.9->ptitprince) (21.3)
# Requirement already satisfied: pillow>=8 in /Users/Alli_1/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.9->ptitprince) (9.2.0)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.0-cp39-cp39-macosx_10_9_x86_64.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.5/265.5 kB 10.2 MB/s eta 0:00:00
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/Alli_1/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.9->ptitprince) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/Alli_1/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.9->ptitprince) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/Alli_1/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.9->ptitprince) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/Alli_1/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.9->ptitprince) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /Users/Alli_1/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.9->ptitprince) (0.11.0)
# Requirement already satisfied: pandas>=1.2 in /Users/Alli_1/opt/anaconda3/lib/python3.9/site-packages (from seaborn>=0.13.2->ptitprince) (2.3.3)
# Requirement already satisfied: zipp>=3.1.0 in /Users/Alli_1/opt/anaconda3/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.9->ptitprince) (3.8.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/Alli_1/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.2->seaborn>=0.13.2->ptitprince) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/Alli_1/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.2->seaborn>=0.13.2->ptitprince) (2025.3)
# Requirement already satisfied: six>=1.5 in /Users/Alli_1/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.9->ptitprince) (1.16.0)
# Building wheels for collected packages: ptitprince
#   Building wheel for ptitprince (pyproject.toml) ... done
#   Created wheel for ptitprince: filename=ptitprince-0.3.1-py3-none-any.whl size=16216 sha256=e3dfb22d38e63fe9a2ec1811aa619073a5ef0b26ce06ff590965839f073b2eb8
#   Stored in directory: /Users/Alli_1/Library/Caches/pip/wheels/c3/9f/12/82378b46e49e957ed7b4efd364d1d28c6d5df552c023ebcc36
# Successfully built ptitprince
# Installing collected packages: importlib-resources, contourpy, matplotlib, ptitprince
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.5.2
#     Uninstalling matplotlib-3.5.2:
#       Successfully uninstalled matplotlib-3.5.2
# Successfully installed contourpy-1.3.0 importlib-resources-6.5.2 matplotlib-3.9.4 ptitprince-0.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import ptitprince as pt

# %%
df = pd.read_csv('/Users/Alli_1/Documents/Repos/fbi_stolen_art_research/Data/nsaf_books-watercolor-painting_sample.csv',na_values=['NA'])

# %%
df['duration'] = df['TP_End']-df['TP_Start'] + 1

# %%
df['mid_year'] = df['TP_Start'] + (df['duration'] / 2)

# %%
#30 books in sample
books = df[df['Category'] == 'Books and Ephemera']

# %%
#31 drawings and watercolors in sample
dwcs = df[df['Category'] == 'Drawings and Watercolors']

# %%
#169 paintings in sample
paintings = df[df['Category'] == 'Paintings']
